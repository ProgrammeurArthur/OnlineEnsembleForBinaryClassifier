# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in ./venv/lib/python3.10/site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in ./venv/lib/python3.10/site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.10/site-packages (from pandas) (2023.4)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from IPython.display import display
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os


path_results = "SMTP"
ensemble = "ensemble_voting"
simulations = [
    "ARFClassifier_resultados",
    "BernoulliNB_resultados",
    "ensemble_AdaBoostClassifier_resultados",
    "ensemble_ADWINBaggingClassifier_resultados",
    "ensemble_ADWINBoostingClassifier_resultados",
    "ensemble_BaggingClassifier_resultados",
    #"ensemble_best_model_resultados",
    "ensemble_voting_resultados",
    "ensemble_BOLEClassifier_resultados",
    "ensemble_LeveragingBaggingClassifier_resultados",
    "ensemble_SRPClassifier_resultados",
    "ensemble_StackingClassifier_resultados",
    "ensemble_VotingClassifier_resultados",
    "forest_AMFClassifier_resultados",
    "HardSamplingClassifier_resultados",
    "linear_model_PAClassifier_resultados",
    "linear_model_SoftmaxRegression_resultados",
    "LogisticRegression_resultados",
    "model_GaussianNB_resultados",
    "model_KNNClassifier_resultados",
    "model_linear_ALMAClassifier_resultados",
    "OneVsOneClassifier_resultados",
    "OneVsRestClassifier_resultados",
    "OutputCodeClassifier_resultados",
    "Perceptron_resultados",
    "RandomOverSampler_resultados",
    "RandomSampler_resultados",
    "RandomUnderSampler_resultados",
    "tree_ExtremelyFastDecisionTreeClassifier_resultados",
    "tree_HoeffdingAdaptiveTreeClassifier_resultados",
    "tree_HoeffdingTreeClassifier_resultados",
    
    
    
]

all_logs = []

def load_data():
    for s in simulations:
        df = pd.read_csv('{}/{}/{}.csv'.format(path_results,ensemble, s), sep=',')
        #df = pd.read_csv('{}.csv'.format( s), sep=',')
        all_logs.append(df)

# %% [markdown]
# ## Load CSV Data

# %%
load_data()
all_logs = pd.concat(all_logs)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 load_data()
#       2 all_logs = pd.concat(all_logs)
#
# Cell In[29], line 50, in load_data()
#      48 def load_data():
#      49     for s in simulations:
# ---> 50         df = pd.read_csv('{}/{}/{}.csv'.format(path_results,ensemble, s), sep=',')
#      51         #df = pd.read_csv('{}.csv'.format( s), sep=',')
#      52         all_logs.append(df)
#
# File ~/TCC/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File ~/TCC/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File ~/TCC/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File ~/TCC/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File ~/TCC/venv/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'SMTP/ensemble_voting/ensemble_best_model_resultados.csv'

# %% [markdown]
# # Tabular Data

# %% [markdown]
# ## One plot per base model

# %%
# # This code plots one plot per Algorithm
import seaborn as sns
from matplotlib.ticker import PercentFormatter

algs = all_logs['Algorithm'].unique()
for alg in algs:

    dataframe = all_logs[all_logs['Algorithm'] == alg]

    plt.figure(figsize=(15, 7))
    sns.set(font_scale=1, style="whitegrid")

    g = sns.lineplot(
        data=dataframe,
        x="Round",
        y='Accuracy',
        markers=False,
        dashes=False,

    )

    g.set_xlabel("Data point", fontsize = 19)
    g.set_ylabel("Accuracy", fontsize = 19)
    plt.rcParams['figure.max_open_warning'] = 50
    plt.title("Metric Accuracy - {}".format(alg), fontsize=20)

# %% [markdown]
# # All Models used by Ensemble

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import PercentFormatter


ensemble_df = pd.read_csv(
    'Bananas/ensemble_best_model/ensemble_best_model_resultados.csv', sep=',')

plt.figure(figsize=(8, 4))
sns.set(font_scale=1, style="ticks")
ax = sns.scatterplot(
    data=ensemble_df,
    x="Round",
    y="Algorithm",
    hue="Algorithm",
    style="Algorithm",
    # sizes=(6, 10),
    color=".1",
    marker="+",
    legend=False
)
plt.legend([],[], frameon=False)
# plt.title('Example Plot')

plt.xlabel('Data Points')
plt.ylabel('Base Learners')
print(ensemble_df['Algorithm'].value_counts())
# Out:
# Algorithm
# model_KNNClassifier     2853
# forest_AMFClassifier    2430
# LogisticRegression         8
# BernoulliNB                7
# RandomOverSampler          2
# Name: count, dtype: int64

# %% [markdown]
# ## All base model's Metrics in one plot
# Take care when using large datasets because this function takes long time.

# %%
# This code plots one plot per Algorithm
import seaborn as sns
from matplotlib.ticker import PercentFormatter
# sns.set_style("whitegrid")
sns.set_style("ticks")
# all_logs['R2'] = np.where(all_logs['R2'] < 0, 0, all_logs['R2'])
# all_logs['R2'] = all_logs['R2'].clip(lower=0)

# temp_date = all_logs
# temp_date['MAE'] = temp_date['MAE'].clip(lower=0, upper=3)
# temp_date = temp_date[(temp_date['Algorithm'] == 'KNN Regression') |
#                     #   (temp_date['Algorithm'] == 'HAT Regression') |
#                     #   (temp_date['Algorithm'] == 'HT Regression') |
#                       (temp_date['Algorithm'] == 'SGT')|
#                       (temp_date['Algorithm'] == 'SRP')
#                       ]
# temp_date = temp_date[(temp_date['Round'] < 200000) &(temp_date['Round'] > 20000)]
# temp_date2 = temp_date[temp_date['Algorithm'] == 'Logistic Regression']

# SGT                       638254
# SRP                       154691
# HT Regression             142688
# HAT Regression             62819
# Adaptive Random Forest       568
# KNN Regression               142
# Bagging                      103
# EWA                           28
# Linear Regression              2


plt.figure(figsize=(8, 4))
# sns.set(font_scale=1, style="white")

# g = sns.lineplot(
#     data=temp_date2,
#     x="Round",
#     y='MAE',
#     hue="Algorithm",
#     markers=True,
#     dashes=False,
#     estimator=None,
#     lw=4,
#     legend=False,
#     sizes=(.25, 2.5),
# )
# graph = sns.lineplot(
#     data=temp_date,
#     x="Round",
#     y='Rolling_MAE',
#     hue="Algorithm",
#     markers=True,
#     dashes=False,
#     estimator=None,
#     lw=0.2,
#     legend=True,
# )

graph = sns.lineplot(
    data=all_logs,
    x="Round",
    y='Accuracy',
    hue="Algorithm",
    markers=True,
    dashes=True,
    estimator=None,
    lw=5,
    legend=False,
)



graph.axvline(50000, color='red', linewidth=0.9)
graph.axvline(100000, color='red', linewidth=0.9)
graph.axvline(150000, color='red', linewidth=0.9)

plt.xlabel('Samples')
plt.ylabel('Rolling Accuracy')
# plt.legend(loc='upper left', labels=[
        #    'LogR MAE', 'KNN-R Rolling MAE', 'HAT-T Rolling MAE', 'HT-R Rolling MAE', 'LogR Rolling MAE'])
# sns.despine(offset=-100, trim=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 58
#      31 plt.figure(figsize=(8, 4))
#      32 # sns.set(font_scale=1, style="white")
#      33
#      34 # g = sns.lineplot(
#    (...)
#      55 #     legend=True,
#      56 # )
# ---> 58 graph = sns.lineplot(
#      59     data=all_logs,
#      60     x="Round",
#      61     y='Accuracy',
#      62     hue="Algorithm",
#      63     markers=True,
#      64     dashes=True,
#      65     estimator=None,
#      66     lw=5,
#      67     legend=False,
#      68 )
#      72 graph.axvline(50000, color='red', linewidth=0.9)
#      73 graph.axvline(100000, color='red', linewidth=0.9)
#
# File ~/TCC/venv/lib/python3.10/site-packages/seaborn/relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)
#     481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
#     488             x=x, y=y, hue=hue, size=size, style=style, units=units, weight=weights
#     489         ),
#     490         estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     491         sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     492         legend=legend,
#     493     )
#     495     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     496     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~/TCC/venv/lib/python3.10/site-packages/seaborn/relational.py:216, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     202 def __init__(
#     203     self, *,
#     204     data=None, variables={},
#    (...)
#     210     # the kind of plot to draw, but for the time being we need to set
#     211     # this information so the SizeMapping can use it
#     212     self._default_size_range = (
#     213         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     214     )
# --> 216     super().__init__(data=data, variables=variables)
#     218     self.estimator = estimator
#     219     self.errorbar = errorbar
#
# File ~/TCC/venv/lib/python3.10/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~/TCC/venv/lib/python3.10/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~/TCC/venv/lib/python3.10/site-packages/seaborn/_core/data.py:57, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
# ---> 57     data = handle_data_source(data)
#      58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#
# File ~/TCC/venv/lib/python3.10/site-packages/seaborn/_core/data.py:278, in handle_data_source(data)
#     276 elif data is not None and not isinstance(data, Mapping):
#     277     err = f"Data source must be a DataFrame or Mapping, not {type(data)!r}."
# --> 278     raise TypeError(err)
#     280 return data
#
# TypeError: Data source must be a DataFrame or Mapping, not <class 'list'>.
